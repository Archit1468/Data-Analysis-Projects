# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/HP/Desktop/Data Analysis Project/googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Only Rating is the column in numerical data type.

df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Let's loop through the data and see if there is anything missing value.

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# App - 0.0%
# Category - 0.0%
# Rating - 14.0%
# Reviews - 0.0%
# Size - 0.0%
# Installs - 0.0%
# Type - 0.0%
# Price - 0.0%
# Content Rating - 0.0%
# Genres - 0.0%
# Last Updated - 0.0%
# Current Ver - 0.0%
# Android Ver - 0.0%

# %%
# Count the number of missing values in each column

df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Checking for outlier in the Rating column.

df.boxplot()

# %% [markdown]
# # Data Cleaning

# %%
# As we saw from the above boxplot, there is one outlier in the rating column.

df[df.Rating > 5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Droping the column with the outlier.

df.drop([10472],inplace=True)

# %%
# As we can see the outlier is now removed.

df.boxplot()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000240B27ACC88>]],
#       dtype=object)

# %% [markdown]
# # Data Imputation and Manipulation

# %%
df.median(axis = 0, skipna = True)
# Out:
# Rating        4.3
# Reviews    2094.0
# dtype: float64

# %%
# As we don't want to drop 14% of our rows, that is why we will fill the null values with the median rating value.

df['Rating'].fillna(value=4.3,inplace=True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
# modes of categorical values

print(df['Type'].mode())
print(df['Current Ver'].mode())
print(df['Android Ver'].mode())
# Out:
# 0    Free
# dtype: object
# 0    Varies with device
# dtype: object
# 0    4.1 and up
# dtype: object

# %%
# Fill the missing categorical values with mode

df['Type'].fillna(str(df['Type'].mode().values[0]), inplace=True) #values[0] just in case the cloumn has bimodal values.
df['Current Ver'].fillna(str(df['Current Ver'].mode().values[0]), inplace=True)
df['Android Ver'].fillna(str(df['Android Ver'].mode().values[0]), inplace=True)

# %%
# All the null values in each column have been fixed.

df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## Converting non-numeric data type to numeric.

# %%
# Let's convert Price, Reviews and Installs into Numerical Values to perform Data analysis.

df['Price'] = df['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
df['Price'] = df['Price'].apply(lambda x: float(x))

df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else str(x))
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else str(x))
df['Installs'] = df['Installs'].apply(lambda x: float(x))

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Stats after converting data type.

df.describe()
# Out:
#              Rating       Reviews      Installs         Price
# count  10840.000000  1.084000e+04  1.084000e+04  10840.000000
# mean       4.206476  4.441529e+05  1.546434e+07      1.027368
# std        0.480342  2.927761e+06  8.502936e+07     15.949703
# min        1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01  1.000000e+03      0.000000
# 50%        4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%        4.500000  5.477550e+04  5.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000

# %%
# Finding maximum/minimum values through function
#This function takes the column name as the argument and returns the top and bottom observations in the dataframe
    
    
def max_min_val(col):
    
    
    first = df[col].idxmax() # The idxmax() function returns index of first occurrence of maximum over requested axis.
    first_obs = pd.DataFrame(df.loc[first])
    
    last = df[col].idxmin()
    last_obs = pd.DataFrame(df.loc[last])
    
    min_max_obs = pd.concat([first_obs, last_obs], axis=1)
    
    return min_max_obs

# %%
max_min_val('Rating')
# Out:
#                                          329                      625
# App             Hojiboy Tojiboyev Life Hacks  House party - live chat
# Category                              COMICS                   DATING
# Rating                                     5                        1
# Reviews                                   15                        1
# Size                                     37M                     9.2M
# Installs                                1000                       10
# Type                                    Free                     Free
# Price                                      0                        0
# Content Rating                      Everyone               Mature 17+
# Genres                                Comics                   Dating
# Last Updated                   June 26, 2018            July 31, 2018
# Current Ver                                2                     3.52
# ...

# %%
max_min_val('Reviews')
# Out:
#                               2544               478
# App                       Facebook  Truth or Dare Pro
# Category                    SOCIAL             DATING
# Rating                         4.1                4.3
# Reviews                   78158306                  0
# Size            Varies with device                20M
# Installs                     1e+09                 50
# Type                          Free               Paid
# Price                            0               1.49
# Content Rating                Teen               Teen
# Genres                      Social             Dating
# Last Updated        August 3, 2018  September 1, 2017
# Current Ver     Varies with device                  1
# Android Ver     Varies with device         4.0 and up

# %%
max_min_val('Price')
# Out:
#                                     4367  \
# App             I'm Rich - Trump Edition
# Category                       LIFESTYLE
# Rating                               3.6
# Reviews                              275
# Size                                7.3M
# Installs                           10000
# Type                                Paid
# Price                                400
# Content Rating                  Everyone
# Genres                         Lifestyle
# Last Updated                 May 3, 2018
# Current Ver                        1.0.1
# Android Ver                   4.1 and up
#
#                                                           0
# App             Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                        ART_AND_DESIGN
# Rating                                                     4.1
# Reviews                                                    159
# Size                                                       19M
# ...

# %% [markdown]
# # Data Visualization

# %%
grp = df.groupby('Category')
x = grp['Rating'].agg(np.mean)
y = grp['Price'].agg(np.sum)
z = grp['Reviews'].agg(np.mean)
k = grp['Installs'].agg(np.mean)

print(x)
print(y)
print(z)
print(k)
# Out:
# Category
# ART_AND_DESIGN         4.355385
# AUTO_AND_VEHICLES      4.205882
# BEAUTY                 4.283019
# BOOKS_AND_REFERENCE    4.335498
# BUSINESS               4.182391
# COMICS                 4.160000
# COMMUNICATION          4.180103
# DATING                 4.025641
# EDUCATION              4.388462
# ENTERTAINMENT          4.126174
# EVENTS                 4.395313
# FAMILY                 4.204564
# FINANCE                4.151639
# FOOD_AND_DRINK         4.185827
# GAME                   4.286888
# HEALTH_AND_FITNESS     4.280059
# HOUSE_AND_HOME         4.211364
# LIBRARIES_AND_DEMO     4.207059
# LIFESTYLE              4.131414
# MAPS_AND_NAVIGATION    4.075182
# MEDICAL                4.216199
# NEWS_AND_MAGAZINES     4.161837
# PARENTING              4.300000
# PERSONALIZATION        4.328827
# PHOTOGRAPHY            4.197910
# PRODUCTIVITY           4.226651
# SHOPPING               4.263077
# SOCIAL                 4.261017
# SPORTS                 4.236458
# ...

# %%
# Which category of apps recieve the highest rating.

plt.figure(figsize=(16,7))
plt.plot(x,'ro', color='r')
plt.xticks(rotation=90)
plt.title('Category wise Rating')
plt.xlabel('Categories-->')
plt.ylabel('Rating-->')
plt.show()

# %%
# What people have been spending the money on most.

plt.figure(figsize=(16,5))
plt.plot(y,'^k:', color='b')
plt.xticks(rotation=90)
plt.title('Category wise Pricing')
plt.xlabel('Categories-->')
plt.ylabel('Prices-->')
plt.show()

# %%
# Which category of apps recieve the most number of reviews.

plt.figure(figsize=(16,5))
plt.plot(z,'bs', color='g')
plt.xticks(rotation=90)
plt.title('Category wise Reviews')
plt.xlabel('Categories-->')
plt.ylabel('Reviews-->')
plt.show()

# %%
# Which category of apps are being installed the most.

plt.figure(figsize=(16,5))
plt.plot(k,'bo', color='c')
plt.xticks(rotation=90)
plt.title('Category wise Rating')
plt.xlabel('Categories-->')
plt.ylabel('Rating-->')
plt.show()
